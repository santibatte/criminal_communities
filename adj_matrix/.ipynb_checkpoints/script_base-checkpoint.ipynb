# %%
#_____________________
#I-AMBIENTE
#_____________________
#paquetes
#para limpieza
import numpy as np
import pandas as pd
#para matriz rala
import scipy.sparse
from scipy.sparse import csr_matrix
#para grafos
import networkx as nx
#para graficar
import matplotlib.pyplot as plt

# %%
#datos
df = pd.read_csv("Cooffending.csv")

# %%
#_____________________
#II-LIMPIEZA
#_____________________
#elimino filas duplicadas
df=df.drop_duplicates(subset =["OffenderIdentifier","CrimeIdentifier"])

# %%
df
# Out:
#          OffenderIdentifier OffenderGender  CrimeIdentifier  CrimeType1  \
# 0                         1              F          1085034      3530.0
# 1                         2              F          1431379      1430.0
# 2                         4              M           167174      1430.0
# 3                         5              M          1179096      1420.0
# 4                        17              M          1270690      1625.0
# ...                     ...            ...              ...         ...
# 1280454              670532              F          1112491      1330.0
# 1280455              670533              M            78081     21702.0
# 1280456              670534              M           187904     21201.0
# 1280457              670535              M           523837     21704.0
# 1280458              670536              M          1632652     21101.0
#
#          CrimeType2  CrimeType3  CrimeType4  Municipality  CrimeLocation  \
# 0               NaN         NaN         NaN         58227            2.0
# 1               NaN         NaN         NaN         94068            5.0
# 2           21702.0         NaN         NaN         49058            2.0
# 3               NaN         NaN         NaN         65005           71.0
# 4               NaN         NaN         NaN         23027            NaN
# ...             ...         ...         ...           ...            ...
# 1280454         NaN         NaN         NaN         58227           34.0
# 1280455         NaN         NaN         NaN         46075           10.0
# 1280456     21702.0         NaN         NaN         31015            1.0
# 1280457         NaN         NaN         NaN         98806            1.0
# 1280458         NaN         NaN         NaN         97802            1.0
#
#          NumberYouthOffenders  NumberAdultOffenders   CrimeDate  CrimeYear
# 0                           0                     1  12/17/2005       2005
# 1                           0                     1  04/23/2008       2008
# 2                           0                     1  03/06/2008       2008
# 3                           0                     1  08/21/2008       2008
# 4                           0                     3  04/30/2003       2003
# ...                       ...                   ...         ...        ...
# 1280454                     0                     1  03/26/2009       2009
# 1280455                     0                     4  06/29/2009       2009
# 1280456                     0                     4  03/16/2009       2009
# 1280457                     0                     1  10/18/2009       2009
# 1280458                     0                     2  11/24/2008       2008
#
# [1279987 rows x 13 columns]

# %%
#formato adecuado a las columnas de interes
for col in ['CrimeIdentifier', 'OffenderIdentifier']:
    df[col] = df[col].astype('category')
for col in ['CrimeIdentifier', 'OffenderIdentifier']:
    df[col] = df[col].astype('int64')
    
#modifico el numero de crimen y de criminal para que sean numeros consecutivos
#este paso es importante para reducir el tamaño de la matriz a justo lo que necestiamos
df['Crimen'] = pd.factorize(df['CrimeIdentifier'])[0] 
df['Criminales'] = pd.factorize(df['OffenderIdentifier'])[0] 

#convierto a np array (para hacer más rapido la matriz rala)
column=df['Crimen']
column=np.array(column)
row=df['Criminales']
row=np.array(row)
df[['Criminales','Crimen']]
# Out:
#          Criminales   Crimen
# 0                 0        0
# 1                 1        1
# 2                 2        2
# 3                 3        3
# 4                 4        4
# ...             ...      ...
# 1280454      539588  1164834
# 1280455      539589  1164632
# 1280456      539590  1164770
# 1280457      539591  1164835
# 1280458      539592  1164826
#
# [1279987 rows x 2 columns]

# %%
#agrego una columna de unos para indicar el match
valor=np.ones((1279987,), dtype=int)
f=np.column_stack([valor,row,column])
f
# Out:
# array([[      1,       0,       0],
#        [      1,       1,       1],
#        [      1,       2,       2],
#        ...,
#        [      1,  539590, 1164770],
#        [      1,  539591, 1164835],
#        [      1,  539592, 1164826]])

# %%
#_____________________
#III-Matrices
#_____________________
#datos como matriz rala
crime_matrix = csr_matrix((f[:,0], (f[:,1], f[:,2])), shape=(row.max() + 1, f[:,2].max() + 1))

# %%
#matriz de adjacencia
A=crime_matrix*crime_matrix.T

# %%
#creo objeto grafo
# ceros en la diagonal (no self loops)
A.setdiag(0)
# me quedo solo con los cruces donde hubo crimenes en comun
A.eliminate_zeros()
# creo grafo
G = nx.from_scipy_sparse_matrix(A)
# elimino los nodos sin ningun edge
G.remove_nodes_from(list(nx.isolates(G)))

# %%
#_____________________
#IV-JUGUEMOS
#_____________________

#datos basicos
G.number_of_nodes()#cantidad de nodos
G.number_of_edges()#cantidad de edges

# %%
#Histograma de coeficiente de cluster
# el paquete networks nos permite sacar cualquier metrica de centralidad (eigenvector, betweeness etc)
h=nx.clustering(G)
data = list(h.items())
H=np.array(data)
plt.hist(H[:,1])
plt.show()

# %%
#red filtrando solo conexiones con pesos altos
#aqui ya vemos una estructura mejor

#repetimos pasos anteriores para tener otro objeto G diferente y no empalmar operaciones
G_2 = nx.from_scipy_sparse_matrix(A)
G_2.remove_nodes_from(list(nx.isolates(G)))

#este loop recorta todos los nodos con menos edges que el numero que determinemos
G_2_edge_list = list( G_2.edges() )
G_2_edge_weight_dict = nx.get_edge_attributes(G_2, 'weight' )
for e in G_2_edge_list:
    if G_2_edge_weight_dict[e] < 30: #aqui eliges el punto de corte (1 o 2 o 5 o 100 dependiendo el problema)
        G_2.remove_edge(e[0],e[1])
G_2.remove_nodes_from(list(nx.isolates(G_2)))
G_2.number_of_nodes()
# Out:
# 66

# %%
# graficamos red para nuestra grafica filtrada por peso
nx.draw(G_2, pos=nx.drawing.nx_agraph.graphviz_layout(G_2), with_labels=True)
#con un punto de corte de 30 delitos podemos ver algunas pequeños componentes sopechosos 
# 30 delitos en comun es mucho! seguro aqui algo huele mal
